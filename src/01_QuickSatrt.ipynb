# %% [markdown]
# ## import NumPy

# %%
import numpy as np

# %%
# Create a NumPy array from a Python list
array = np.array([1 ,2 ,3 ,4])

print("array data =" ,array)
print("array length =", array.size)
# Out:
# array data = [1 2 3 4]
# array length = 4
